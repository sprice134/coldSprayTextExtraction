# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import mean_absolute_error
from difflib import SequenceMatcher



def calculate_similarity(exp1, exp2):
    similarity = 0

    # Numeric field similarity (absolute difference)
    for field in ['yield_strength_value', "ultimate_tensile_strength_value", 'ductility_value', 'hardness_value', 'modulus_value']:
        val1 = exp1.get(field, "NA")
        val2 = exp2.get(field, "NA")
        
        # Convert to numeric if possible, otherwise treat "NA" as 0
        try:
            val1 = float(val1) if val1 != "NA" else 0.0
            val2 = float(val2) if val2 != "NA" else 0.0
        except ValueError:
            val1 = val2 = 0.0  # Fallback for unexpected non-numeric strings
        
        similarity -= abs(val1 - val2)  # Penalize based on difference

    # Text field similarity (SequenceMatcher)
    notes1 = exp1.get("notes", "")
    notes2 = exp2.get("notes", "")
    similarity += SequenceMatcher(None, notes1, notes2).ratio()  # Add similarity score

    return similarity

def rmse(gt_values, ext_values):
    return np.sqrt(np.mean((np.array(gt_values) - np.array(ext_values)) ** 2))

def calculate_performance(ground_truth, extracted, penalty=1.0):
    num_ground_truth = len(ground_truth)
    num_extracted = len(extracted)
    similarity_matrix = np.zeros((num_ground_truth, num_extracted))

    # Calculate similarity matrix
    for i, gt in enumerate(ground_truth):
        for j, ext in enumerate(extracted):
            similarity_matrix[i, j] = calculate_similarity(gt, ext)

    # Optimal matching using Hungarian Algorithm
    row_ind, col_ind = linear_sum_assignment(-similarity_matrix)  # Maximize similarity

    # Create matched pairs and identify unmatched
    matched_pairs = []
    matched_gt = set(row_ind)
    matched_ext = set(col_ind)
    
    for i, j in zip(row_ind, col_ind):
        matched_pairs.append((ground_truth[i], extracted[j]))

    unmatched_gt = set(range(num_ground_truth)) - matched_gt
    unmatched_ext = set(range(num_extracted)) - matched_ext

    # Calculate individual performance metrics (normalized RMSE)
    field_rmse = {}
    normalized_losses = []

    for field in ['yield_strength_value', "ultimate_tensile_strength_value", 'ductility_value', 'hardness_value', 'modulus_value']:
        gt_values = []
        ext_values = []

        # Process matched pairs only
        for gt, ext in matched_pairs:
            gt_val = gt.get(field, "NA")
            ext_val = ext.get(field, "NA")
            # Convert "NA" or invalid types to 0
            gt_val = float(gt_val) if isinstance(gt_val, (int, float)) else 0
            ext_val = float(ext_val) if isinstance(ext_val, (int, float)) else 0
            gt_values.append(gt_val)
            ext_values.append(ext_val)

        # Compute RMSE and normalize
        if gt_values and ext_values:
            error = rmse(gt_values, ext_values)
            max_gt_value = max(gt_values) if gt_values else 1  # Avoid division by 0
            normalized_loss = error / max_gt_value if max_gt_value != 0 else 0
            field_rmse[field] = normalized_loss
            normalized_losses.append(normalized_loss)

    # Calculate overall loss
    avg_normalized_loss = np.mean(normalized_losses) if normalized_losses else 0
    if num_ground_truth > 0:
        percent_error = abs(num_extracted - num_ground_truth) / num_ground_truth
    else:
        # Apply penalty proportional to the number of extracted items
        percent_error = num_extracted
    overall_loss = avg_normalized_loss + (percent_error * penalty)

    # Display Results
    results = {
        "Field RMSE": field_rmse,  # Normalized individual metrics
        "Overall Loss": overall_loss,  # Penalized overall performance
        "Similarity Matrix": similarity_matrix,
        "Unmatched Ground Truth": unmatched_gt,
        "Unmatched Extracted": unmatched_ext
    }
    return results

# %%
ground_truth = [
    {
        "yield_strength_value": "NA",
        "yield_strength_units": "NA",
        "ultimate_tensile_strength_value": 70,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": "NA",
        "ductility_units": "NA",
        "hardness_value": 85,
        "hardness_units": "HV",
        "modulus_value": "NA",
        "modulus_units": "NA",
        "notes": "As-sprayed deposit from as-atomized (naturally aged) Al6061 powder at Tgas=500°C and pgas=3 MPa"
    },
    {
        "yield_strength_value": "NA",
        "yield_strength_units": "NA",
        "ultimate_tensile_strength_value": 107,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": "NA",
        "ductility_units": "NA",
        "hardness_value": 69,
        "hardness_units": "HV",
        "modulus_value": "NA",
        "modulus_units": "NA",
        "notes": "As-sprayed deposit from solution-annealed Al6061 powder at Tgas=500°C and pgas=3 MPa"
    }
]

extracted = [
    {
        "yield_strength_value": "NA",
        "yield_strength_units": "NA",
        "ultimate_tensile_strength_value": 70,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": "NA",
        "ductility_units": "NA",
        "hardness_value": 85,
        "hardness_units": "HV",
        "modulus_value": "NA",
        "modulus_units": "NA",
        "notes": "As-sprayed deposit from as-atomized (naturally aged) Al6061 powder at Tgas=500°C and pgas=3 MPa"
    },
    {
        "yield_strength_value": "NA",
        "yield_strength_units": "NA",
        "ultimate_tensile_strength_value": 107,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": "NA",
        "ductility_units": "NA",
        "hardness_value": 69,
        "hardness_units": "HV",
        "modulus_value": "NA",
        "modulus_units": "NA",
        "notes": "As-sprayed deposit from solution-annealed Al6061 powder at Tgas=500°C and pgas=3 MPa"
    }
]

results = calculate_performance(ground_truth, extracted)

for i in results:
    print(i)
    print(results[i])
    print('-'*30)
# Out:
# Field RMSE
# {'yield_strength_value': 0, 'ultimate_tensile_strength_value': np.float64(0.0), 'ductility_value': 0, 'hardness_value': np.float64(0.0), 'modulus_value': 0}
# ------------------------------
# Overall Loss
# 0.0
# ------------------------------
# Similarity Matrix
# [[  1.         -52.19553073]
#  [-52.16201117   1.        ]]
# ------------------------------
# Unmatched Ground Truth
# set()
# ------------------------------
# Unmatched Extracted
# set()
# ------------------------------

# %%
# Example Ground Truth and Extracted Data
ground_truth = [
    {
        "yield_strength_value": 114,
        "yield_strength_units": "MPA",
        "ultimate_tensile_strength_value": 70,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 3,
        "ductility_units": "%",
        "hardness_value": 85,
        "hardness_units": "HV",
        "modulus_value": "NA",
        "modulus_units": "NA",
        "notes": "As-sprayed deposit from as-atomized (naturally aged) Al6061 powder at Tgas=500°C and pgas=3 MPa"
    },
    {
        "yield_strength_value": "NA",
        "yield_strength_units": "NA",
        "ultimate_tensile_strength_value": 107,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 5,
        "ductility_units": "%",
        "hardness_value": 69,
        "hardness_units": "HV",
        "modulus_value": "NA",
        "modulus_units": "NA",
        "notes": "As-sprayed deposit from solution-annealed Al6061 powder at Tgas=500°C and pgas=3 MPa"
    }
]

extracted = [
    {
        "yield_strength_value": 112,
        "yield_strength_units": "MPA",
        "ultimate_tensile_strength_value": 70,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 3.1,
        "ductility_units": "%",
        "hardness_value": 85,
        "hardness_units": "HV",
        "modulus_value": "NA",
        "modulus_units": "NA",
        "notes": "As-sprayed deposit from as-atomized (naturally aged) Al6061 powder at Tgas=500°C and pgas=3 MPa"
    },
    {
        "yield_strength_value": "NA",
        "yield_strength_units": "NA",
        "ultimate_tensile_strength_value": 107,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 5,
        "ductility_units": "%",
        "hardness_value": 69,
        "hardness_units": "HV",
        "modulus_value": "NA",
        "modulus_units": "NA",
        "notes": "As-sprayed deposit from solution-annealed Al6061 powder at Tgas=500°C and pgas=3 MPa"
    }
]
results = calculate_performance(ground_truth, extracted)

for i in results:
    print(i)
    print(results[i])
    print('-'*30)
# Out:
# Field RMSE
# {'yield_strength_value': np.float64(0.012405382126079782), 'ultimate_tensile_strength_value': np.float64(0.0), 'ductility_value': np.float64(0.014142135623730965), 'hardness_value': np.float64(0.0), 'modulus_value': 0}
# ------------------------------
# Overall Loss
# 0.00530950354996215
# ------------------------------
# Similarity Matrix
# [[  -1.1        -168.19553073]
#  [-166.06201117    1.        ]]
# ------------------------------
# Unmatched Ground Truth
# set()
# ------------------------------
# Unmatched Extracted
# set()
# ------------------------------

# %%
ground_truth = [
    {
        "yield_strength_value": 250.3,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 268.2,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 1.2,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 54.5,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set I (longitudinal); powder exposed to humid air"
    },
    {
        "yield_strength_value": 251.2,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 271.3,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 1.0,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 55.3,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set I (transverse); powder exposed to humid air"
    },
    {
        "yield_strength_value": 230.6,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 292.3,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 6.9,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 71.0,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set II (longitudinal); no humid air exposure"
    },
    {
        "yield_strength_value": 231.0,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 289.6,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 5.7,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 70.3,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set II (transverse); no humid air exposure"
    },
    {
        "yield_strength_value": 249.5,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 289.6,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 3.9,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 67.5,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set III (longitudinal)"
    }
]

extracted = [
    {
        "yield_strength_value": 250.3,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 268.2,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 1.2,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 54.5,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set I (longitudinal); powder exposed to humid air"
    },
    {
        "yield_strength_value": 251.2,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 271.3,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 1.0,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 55.3,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set I (transverse); powder exposed to humid air"
    },
    {
        "yield_strength_value": 230.6,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 292.3,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 6.9,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 71.0,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set II (longitudinal); no humid air exposure"
    },
    {
        "yield_strength_value": 231.0,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 289.6,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 5.7,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 70.3,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set II (transverse); no humid air exposure"
    }
]

results = calculate_performance(ground_truth, extracted)

for i in results:
    print(i)
    print(results[i])
    print('-'*30)
# Out:
# Field RMSE
# {'yield_strength_value': np.float64(0.0), 'ultimate_tensile_strength_value': np.float64(0.0), 'ductility_value': np.float64(0.0), 'hardness_value': 0, 'modulus_value': np.float64(0.0)}
# ------------------------------
# Overall Loss
# 0.2
# ------------------------------
# Similarity Matrix
# [[  1.          -4.12048193 -65.16564417 -60.29192547]
#  [ -4.10843373   1.         -62.47950311 -57.36981132]
#  [-65.16564417 -62.49192547   1.          -4.12820513]
#  [-60.27950311 -57.36981132  -4.11538462   1.        ]
#  [-37.11985816 -34.4381295  -27.27647059 -22.41343284]]
# ------------------------------
# Unmatched Ground Truth
# {4}
# ------------------------------
# Unmatched Extracted
# set()
# ------------------------------

# %%
ground_truth = [
    {
        "yield_strength_value": 250.3,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 268.2,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 1.2,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 54.5,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set I (longitudinal); powder exposed to humid air"
    },
    {
        "yield_strength_value": 251.2,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 271.3,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 1.0,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 55.3,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set I (transverse); powder exposed to humid air"
    },
    {
        "yield_strength_value": 230.6,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 292.3,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 6.9,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 71.0,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set II (longitudinal); no humid air exposure"
    },
    {
        "yield_strength_value": 231.0,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 289.6,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 5.7,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 70.3,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set II (transverse); no humid air exposure"
    },
    {
        "yield_strength_value": 249.5,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 289.6,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 3.9,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 67.5,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set III (longitudinal)"
    }
]

extracted = []

results = calculate_performance(ground_truth, extracted)

for i in results:
    print(i)
    print(results[i])
    print('-'*30)
# Out:
# Field RMSE
# {}
# ------------------------------
# Overall Loss
# 1.0
# ------------------------------
# Similarity Matrix
# []
# ------------------------------
# Unmatched Ground Truth
# {0, 1, 2, 3, 4}
# ------------------------------
# Unmatched Extracted
# set()
# ------------------------------

# %%
ground_truth = []

extracted = [
    {
        "yield_strength_value": 250.3,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 268.2,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 1.2,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 54.5,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set I (longitudinal); powder exposed to humid air"
    },
    {
        "yield_strength_value": 251.2,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 271.3,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 1.0,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 55.3,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set I (transverse); powder exposed to humid air"
    },
    {
        "yield_strength_value": 230.6,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 292.3,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 6.9,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 71.0,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set II (longitudinal); no humid air exposure"
    },
    {
        "yield_strength_value": 231.0,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 289.6,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 5.7,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 70.3,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set II (transverse); no humid air exposure"
    },
    {
        "yield_strength_value": 249.5,
        "yield_strength_units": "MPa",
        "ultimate_tensile_strength_value": 289.6,
        "ultimate_tensile_strength_units": "MPa",
        "ductility_value": 3.9,
        "ductility_units": "%",
        "hardness_value": "NA",
        "hardness_units": "NA",
        "modulus_value": 67.5,
        "modulus_units": "GPa",
        "notes": "As-sprayed AL 6061 from processing set III (longitudinal)"
    }
]


results = calculate_performance(ground_truth, extracted)

for i in results:
    print(i)
    print(results[i])
    print('-'*30)
# Out:
# Field RMSE
# {}
# ------------------------------
# Overall Loss
# 5.0
# ------------------------------
# Similarity Matrix
# []
# ------------------------------
# Unmatched Ground Truth
# set()
# ------------------------------
# Unmatched Extracted
# {0, 1, 2, 3, 4}
# ------------------------------

# %%
import json
file1 = '/Users/sprice/Documents/GitHub/coldSprayTextExtraction/productionalized/modelOutputs/o1mini.json'
file2 = '/Users/sprice/Documents/GitHub/coldSprayTextExtraction/productionalized/misc/groundTruthArticles.json'

def compare_json_files(file1, file2):
    with open(file1, 'r') as f1, open(file2, 'r') as f2:
        data1 = json.load(f1)['outputs']
        data2 = json.load(f2)['Articles']
        for obj1 in data1:
            for obj2 in data2:
                if obj1 == obj2:
                    extracted = data1[obj1]
                    ground_truth = data2[obj2]
                    # Use the extracted and ground truth values as needed
                    print(f"Extracted: {extracted}, Ground Truth: {ground_truth}")
                    results = calculate_performance(ground_truth, extracted)

                    for i in results:
                        print(i)
                        print(results[i])
                        print('-'*30)

compare_json_files(file1, file2)
# Out:
# Extracted: [{'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 61.4, 'modulus_units': 'GPa', 'notes': 'Mean elastic modulus for L/T cold-sprayed specimens was 61.4 ±0.3 GPa'}], Ground Truth: [{'yield_strength': '260', 'ductility': '2.6%', 'hardness': 'NA', 'modulus': '61.4', 'notes': 'He-sprayed Al6061 sample (Al-2-1) with improved particle impact velocity; shows significant tensile strength increase and ductility.'}]
# Field RMSE
# {'yield_strength_value': 0, 'ultimate_tensile_strength_value': 0, 'ductility_value': 0, 'hardness_value': 0, 'modulus_value': 0}
# ------------------------------
# Overall Loss
# 0.0
# ------------------------------
# Similarity Matrix
# [[-61.17114428]]
# ------------------------------
# Unmatched Ground Truth
# set()
# ------------------------------
# Unmatched Extracted
# set()
# ------------------------------
# Extracted: [{'yield_strength_value': 250.3, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 268.2, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 1.2, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 54.5, 'modulus_units': 'GPa', 'notes': 'Processing set I, longitudinal orientation'}, {'yield_strength_value': 251.2, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 271.3, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 1.0, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 55.3, 'modulus_units': 'GPa', 'notes': 'Processing set I, transverse orientation'}, {'yield_strength_value': 230.6, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 292.3, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 6.9, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 71.0, 'modulus_units': 'GPa', 'notes': 'Processing set II, longitudinal orientation'}, {'yield_strength_value': 231.0, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 289.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 5.7, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 70.3, 'modulus_units': 'GPa', 'notes': 'Processing set II, transverse orientation'}, {'yield_strength_value': 249.5, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 289.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3.9, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 67.5, 'modulus_units': 'GPa', 'notes': 'Processing set III, longitudinal orientation'}], Ground Truth: [{'yield_strength_value': 250.3, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 268.2, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 1.2, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 54.5, 'modulus_units': 'GPa', 'notes': 'As-sprayed AL 6061 from processing set I (longitudinal); powder exposed to humid air'}, {'yield_strength_value': 251.2, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 271.3, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 1.0, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 55.3, 'modulus_units': 'GPa', 'notes': 'As-sprayed AL 6061 from processing set I (transverse); powder exposed to humid air'}, {'yield_strength_value': 230.6, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 292.3, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 6.9, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 71.0, 'modulus_units': 'GPa', 'notes': 'As-sprayed AL 6061 from processing set II (longitudinal); no humid air exposure'}, {'yield_strength_value': 231.0, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 289.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 5.7, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 70.3, 'modulus_units': 'GPa', 'notes': 'As-sprayed AL 6061 from processing set II (transverse); no humid air exposure'}, {'yield_strength_value': 249.5, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 289.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3.9, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 67.5, 'modulus_units': 'GPa', 'notes': 'As-sprayed AL 6061 from processing set III (longitudinal)'}]
# Field RMSE
# {'yield_strength_value': np.float64(0.0), 'ultimate_tensile_strength_value': np.float64(0.0), 'ductility_value': np.float64(0.0), 'hardness_value': 0, 'modulus_value': np.float64(0.0)}
# ------------------------------
# Overall Loss
# 0.0
# ------------------------------
# Similarity Matrix
# [[  0.50793651  -4.70967742 -65.49606299 -60.712      -37.4       ]
#  [ -4.67741935   0.49180328 -62.88       -57.71219512 -34.78253968]
#  [-65.48760331 -62.89747899   0.52459016  -4.68333333 -27.5796748 ]
#  [-60.66386555 -57.7042735   -4.65         0.50847458 -22.75289256]
#  [-37.33434343 -34.72886598 -27.52       -22.7122449    0.59405941]]
# ------------------------------
# Unmatched Ground Truth
# set()
# ------------------------------
# Unmatched Extracted
# set()
# ------------------------------
# Extracted: [{'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 460, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed condition with higher ultimate tensile strength and lower ductility compared to conventionally processed material'}, {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 0.98, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Nanohardness obtained from feedstock 6061Al powder'}, {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.43, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Nanohardness obtained from CS6061 deposit, particle interior'}, {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.77, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Nanohardness obtained from CS6061 deposit, prior particle boundaries (PPB)'}], Ground Truth: [{'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 440, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-deposited (cold-sprayed) condition'}, {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 490, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3.6, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Stress-relieved condition'}, {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 465, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3.8, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'T6 condition'}]
# Field RMSE
# {'yield_strength_value': 0, 'ultimate_tensile_strength_value': np.float64(0.7759799866030672), 'ductility_value': np.float64(0.722287328078558), 'hardness_value': 0, 'modulus_value': 0}
# ------------------------------
# Overall Loss
# 0.6329867962696584
# ------------------------------
# Similarity Matrix
# [[ -19.7515528  -443.70413793 -444.14134021 -444.53576577]
#  [ -30.39865772 -494.28666667 -494.70058824 -495.10737374]
#  [  -5.65294118 -469.65096774 -470.03555556 -470.4072093 ]]
# ------------------------------
# Unmatched Ground Truth
# set()
# ------------------------------
# Unmatched Extracted
# {3}
# ------------------------------
# Extracted: [{'yield_strength_value': 270, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 319, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 4.43, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'NA'}, {'yield_strength_value': 247, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 314, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 4.96, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'NA'}, {'yield_strength_value': 252, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 316, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 6.4, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'NA'}, {'yield_strength_value': 237, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 310, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 5.18, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'NA'}, {'yield_strength_value': 252, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 315, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 5.2, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'NA'}], Ground Truth: [{'yield_strength_value': 270, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 319, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 4.43, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed 6061 sample 1'}, {'yield_strength_value': 247, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 314, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 4.96, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed 6061 sample 2'}, {'yield_strength_value': 252, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 316, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 6.4, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed 6061 sample 3'}, {'yield_strength_value': 237, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 310, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 5.18, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed 6061 sample 4'}]
# Field RMSE
# {'yield_strength_value': np.float64(0.0), 'ultimate_tensile_strength_value': np.float64(0.0), 'ductility_value': np.float64(0.0), 'hardness_value': 0, 'modulus_value': 0}
# ------------------------------
# Overall Loss
# 0.25
# ------------------------------
# Similarity Matrix
# [[  0.   -28.53 -22.97 -42.75 -22.77]
#  [-28.53   0.    -8.44 -14.22  -6.24]
#  [-22.97  -8.44   0.   -22.22  -2.2 ]
#  [-42.75 -14.22 -22.22   0.   -20.02]]
# ------------------------------
# Unmatched Ground Truth
# set()
# ------------------------------
# Unmatched Extracted
# {4}
# ------------------------------
# Extracted: [{'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 277.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.6, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 64.3, 'modulus_units': 'GPa', 'notes': 'As-deposited via in-situ micro-forging assisted cold spray (MF-CS) process'}, {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 210.8, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 9.5, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Recrystallization annealing (RA) heat treatment'}, {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 314.3, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 7.5, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'T6 heat treatment with precipitation strengthening'}, {'yield_strength_value': 290, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 340, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed AA6061 using helium gas with in-situ micro-forging (MF-CS) [17]'}, {'yield_strength_value': 262, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 286.8, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 2, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 67.5, 'modulus_units': 'GPa', 'notes': 'Cold-sprayed AA6061 using helium gas, reference [18]'}], Ground Truth: [{'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 277.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.6, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 64.3, 'modulus_units': 'GPa', 'notes': 'As-deposited (MF-CS) condition with no post-spray heat treatment'}, {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 298.1, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.9, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 63.2, 'modulus_units': 'GPa', 'notes': 'Stress-relieved (SR) at 175°C for 8 h'}, {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 210.8, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 9.3, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Recrystallization annealed (RA) at 450°C for 2 h'}, {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 314.3, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 7.8, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'T6 heat treatment: solution at 535°C for 1 h, water quench, aging at 175°C for 4 h'}]
# Field RMSE
# {'yield_strength_value': 0, 'ultimate_tensile_strength_value': np.float64(0.01797645561565385), 'ductility_value': np.float64(0.062235682273065716), 'hardness_value': 0, 'modulus_value': np.float64(0.03343701399688956)}
# ------------------------------
# Overall Loss
# 0.27272983037712184
# ------------------------------
# Similarity Matrix
# [[ 3.47826087e-01 -1.39567568e+02 -1.07636842e+02 -4.18885714e+02
#   -2.75524138e+02]
#  [-2.18099099e+01 -1.58980952e+02 -8.57471264e+01 -3.96916814e+02
#   -2.78452809e+02]
#  [-1.39570492e+02  5.15789474e-01 -1.05075510e+02 -4.25241935e+02
#   -4.12620000e+02]
#  [-1.07943590e+02 -1.04967442e+02  1.69696970e-01 -3.20234177e+02
#   -3.62605970e+02]]
# ------------------------------
# Unmatched Ground Truth
# set()
# ------------------------------
# Unmatched Extracted
# {3}
# ------------------------------
