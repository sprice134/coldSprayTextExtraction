# %%
import pandas as pd
import numpy as np
import json
from tools import calculate_similarity, calculate_performance, calculate_performance_V2, pdf_to_text
import os

# %%
json_file = 'articlesJsonTemplate.json'
from openai import OpenAI

with open("../openAiToken.txt", "r") as key_file:
    api_key = key_file.read().strip()
os.environ["OPENAI_API_KEY"] = api_key  # Optionally set it as an environment variable
client = OpenAI(api_key=api_key)

# %%
modelName = "o3-mini"
ARTICLES_JSON = "/Users/sprice/Documents/GitHub/coldSprayTextExtraction/productionalized/modelOutputs3-11/o3-mini_promptv2_high_merged.json"
GROUND_TRUTH_JSON = "misc/groundTruthArticles.json"
SECOND_PASS_PROMPT_FILE = "/Users/sprice/Documents/GitHub/coldSprayTextExtraction/productionalized/misc/promptV2_processExtraction.txt"
OUTPUT_JSON = f"/Users/sprice/Documents/GitHub/coldSprayTextExtraction/productionalized/modelOutputs3-11/{modelName}_promptv2_high_merged_withParams.json"

##########################################
# Main Script
##########################################

def main():
    # 1) Load the articles JSON (already has mechanical properties)
    with open(ARTICLES_JSON, "r") as f:
        articles = json.load(f)

    with open(GROUND_TRUTH_JSON, "r") as f:
        ground_truth_articles = json.load(f)

    with open(SECOND_PASS_PROMPT_FILE, "r") as file:
        second_pass_prompt_template = file.read()

    for article in articles:
        filename = article.get("filename", "UNKNOWN")
        print(f"Processing article: {filename}")

        # Skip certain articles by filename pattern
        if "56" in filename or "89" in filename:
            print("Skipping due to filename containing '56' or '89'.")
            continue

        # Check if article is in ground truth
        # base_name = filename.split('.')[0]
        # if base_name in ground_truth_articles.get('Articles', []):
        #     print("Skipping because article is in ground truth.")
        #     continue

        # Check for PDF existence
        pdf_path = f"documents/{filename}"
        if not os.path.exists(pdf_path):
            print("Skipping because PDF not found.")
            continue

        # 5) Extract text from the PDF
        print(f"Extracting text from: {pdf_path}")
        article_text = pdf_to_text(pdf_path)

        # 6) If the article has 'extractedText' as a list, it means
        #    we have multiple experiments from the first pass
        all_experiments = article.get("extractedText", [])
        if not isinstance(all_experiments, list):
            print("No experiments to process (extractedText is not a list).")
            continue

        # 7) For each experiment, run the second pass
        for experiment in all_experiments:
            # Convert the single experiment to JSON to insert in the prompt
            experiment_str = json.dumps(experiment, ensure_ascii=False)

            # Build the final prompt for the second pass
            second_pass_prompt = (
                f"{second_pass_prompt_template}\n\n"
                f"Here is the article:\n{article_text}\n\n"
                f"Here are the experimental results you must identify the processing parameters for:\n"
                f"{experiment_str}"
            )

            # Send to the LLM
            messages = [
                {"role": "user", "content": second_pass_prompt}
            ]

            print(f"Sending second-pass prompt for {filename} / experiment:\n{experiment}")
            
            # Example usage - adjust as needed for your LLM client
            completion = client.chat.completions.create(
                model=modelName,
                messages=messages,
                reasoning_effort='high'
            )
            model_response = completion.choices[0].message.content.strip()

            # Strip any triple backticks
            if model_response.startswith("```json") and model_response.endswith("```"):
                model_response = model_response[7:-3].strip()

            # Try to parse the returned JSON
            try:
                parsed_params = json.loads(model_response)
            except json.JSONDecodeError:
                print("Error: Could not parse second-pass JSON. Storing raw string.")
                parsed_params = model_response

            # Attach the returned processing parameters to the experiment
            experiment["processing_parameters"] = parsed_params

        # (Optional) Write out partial results after each article, so we don't lose progress
        with open(OUTPUT_JSON, "w") as out_f:
            json.dump(articles, out_f, indent=4)

    print("All done! Final file saved at:", OUTPUT_JSON)


if __name__ == "__main__":
    main()
# Out:
# Processing article: Article_1.pdf
# Extracting text from: documents/Article_1.pdf
# Sending second-pass prompt for Article_1.pdf / experiment:
# {'yield_strength_value': 260, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 2.6, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 61.4, 'modulus_units': 'GPa', 'notes': 'He-sprayed Al6061 sample (Al-2-1) with improved particle impact velocity; shows significant tensile strength increase and ductility.'}
# Processing article: Article_2.pdf
# Skipping because PDF not found.
# Processing article: Article_3.pdf
# Extracting text from: documents/Article_3.pdf
# Sending second-pass prompt for Article_3.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 100, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 85, 'hardness_units': 'HV0.3', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed deposit from solution-annealed (pAS) powder at Tgas=400°C, pgas=3 MPa, g=1.07'}
# Sending second-pass prompt for Article_3.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 75, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 69, 'hardness_units': 'HV0.3', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed deposit from solution-annealed (pAS) powder at Tgas=500°C'}
# Processing article: Article_4.pdf
# Extracting text from: documents/Article_4.pdf
# Processing article: Article_5.pdf
# Extracting text from: documents/Article_5.pdf
# Sending second-pass prompt for Article_5.pdf / experiment:
# {'yield_strength_value': 250.3, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 268.2, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 1.2, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 54.5, 'modulus_units': 'GPa', 'notes': 'As-sprayed AL 6061 from processing set I (longitudinal); powder exposed to humid air'}
# Sending second-pass prompt for Article_5.pdf / experiment:
# {'yield_strength_value': 251.2, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 271.3, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 1.0, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 55.3, 'modulus_units': 'GPa', 'notes': 'As-sprayed AL 6061 from processing set I (transverse); powder exposed to humid air'}
# Sending second-pass prompt for Article_5.pdf / experiment:
# {'yield_strength_value': 230.6, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 292.3, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 6.9, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 71.0, 'modulus_units': 'GPa', 'notes': 'As-sprayed AL 6061 from processing set II (longitudinal); no humid air exposure'}
# Sending second-pass prompt for Article_5.pdf / experiment:
# {'yield_strength_value': 231.0, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 289.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 5.7, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 70.3, 'modulus_units': 'GPa', 'notes': 'As-sprayed AL 6061 from processing set II (transverse); no humid air exposure'}
# Sending second-pass prompt for Article_5.pdf / experiment:
# {'yield_strength_value': 249.5, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 289.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3.9, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 67.5, 'modulus_units': 'GPa', 'notes': 'As-sprayed AL 6061 from processing set III (longitudinal)'}
# Processing article: Article_6.pdf
# Extracting text from: documents/Article_6.pdf
# Sending second-pass prompt for Article_6.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.24, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Average nanoindentation hardness for gas‐atomized Al 6061 powder in the 25–32 μm size range, measured via nanoindentation.'}
# Sending second-pass prompt for Article_6.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.16, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Average nanoindentation hardness for gas‐atomized Al 6061 powder in the 32–38 μm size range, measured via nanoindentation.'}
# Sending second-pass prompt for Article_6.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.12, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Average nanoindentation hardness for gas‐atomized Al 6061 powder in the 38–45 μm size range, measured via nanoindentation.'}
# Sending second-pass prompt for Article_6.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.05, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Average nanoindentation hardness for gas‐atomized Al 6061 powder in the 45–53 μm size range, measured via nanoindentation.'}
# Sending second-pass prompt for Article_6.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.25, 'hardness_units': 'GPa', 'modulus_value': 74.12, 'modulus_units': 'GPa', 'notes': 'EBSD‐informed nanoindentation on a grain of gas‐atomized Al 6061 powder in the [111] crystallographic orientation.'}
# Sending second-pass prompt for Article_6.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 0.73, 'hardness_units': 'GPa', 'modulus_value': 65.34, 'modulus_units': 'GPa', 'notes': 'EBSD‐informed nanoindentation on a grain of gas‐atomized Al 6061 powder in the [101] crystallographic orientation.'}
# Processing article: Article_7.pdf
# Extracting text from: documents/Article_7.pdf
# Sending second-pass prompt for Article_7.pdf / experiment:
# {'yield_strength_value': 255.7, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 293.7, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 4.122, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 66.6, 'modulus_units': 'GPa', 'notes': 'As-sprayed CS Al-6061 tested at 2.5e-4 s^-1 (ASTM E8 specimen)'}
# Sending second-pass prompt for Article_7.pdf / experiment:
# {'yield_strength_value': 252.8, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 291.9, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 4.354, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 66.65, 'modulus_units': 'GPa', 'notes': 'As-sprayed CS Al-6061 tested at 2.5e-3 s^-1 (ASTM E8 specimen)'}
# Sending second-pass prompt for Article_7.pdf / experiment:
# {'yield_strength_value': 253.7, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 293.8, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 4.992, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 69.09, 'modulus_units': 'GPa', 'notes': 'As-sprayed CS Al-6061 tested at 2.5e-2 s^-1 (ASTM E8 specimen)'}
# Sending second-pass prompt for Article_7.pdf / experiment:
# {'yield_strength_value': 250.7, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 296.2, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 4.478, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 66.61, 'modulus_units': 'GPa', 'notes': 'As-sprayed CS Al-6061 tested at 2.5e-1 s^-1 (ASTM E8 specimen)'}
# Sending second-pass prompt for Article_7.pdf / experiment:
# {'yield_strength_value': 250.6, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 285.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3.068, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 67.08, 'modulus_units': 'GPa', 'notes': 'As-sprayed CS Al-6061 tested at 8.81e-3 s^-1 (miniature tensile specimen)'}
# Sending second-pass prompt for Article_7.pdf / experiment:
# {'yield_strength_value': 263.4, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 296.7, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 5.341, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 54.35, 'modulus_units': 'GPa', 'notes': 'As-sprayed CS Al-6061 tested at 9.26e-1 s^-1 (miniature tensile specimen)'}
# Sending second-pass prompt for Article_7.pdf / experiment:
# {'yield_strength_value': 259.0, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 294.7, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 6.91, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed CS Al-6061 tested at 1.25e+2 s^-1 (miniature tensile specimen)'}
# Sending second-pass prompt for Article_7.pdf / experiment:
# {'yield_strength_value': 289.0, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 317.5, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 6.888, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed CS Al-6061 tested at 4.82e+2 s^-1 (miniature tensile specimen)'}
# Processing article: Article_8.pdf
# Extracting text from: documents/Article_8.pdf
# Sending second-pass prompt for Article_8.pdf / experiment:
# {'yield_strength_value': 262.0, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 286.8, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 2.0, 'ductility_units': '%', 'hardness_value': 105.0, 'hardness_units': 'HV', 'modulus_value': 67.5, 'modulus_units': 'GPa', 'notes': 'As-sprayed condition'}
# Sending second-pass prompt for Article_8.pdf / experiment:
# {'yield_strength_value': 147.5, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 195.1, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 13.0, 'ductility_units': '%', 'hardness_value': 65.7, 'hardness_units': 'HV', 'modulus_value': 64.1, 'modulus_units': 'GPa', 'notes': 'Annealed condition'}
# Sending second-pass prompt for Article_8.pdf / experiment:
# {'yield_strength_value': 203.4, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 216.5, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 1.8, 'ductility_units': '%', 'hardness_value': 120.0, 'hardness_units': 'HV', 'modulus_value': 65.1, 'modulus_units': 'GPa', 'notes': 'T6 condition'}
# Processing article: Article_9.pdf
# Extracting text from: documents/Article_9.pdf
# Sending second-pass prompt for Article_9.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 87, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.14, 'ductility_units': '%', 'hardness_value': 77.5, 'hardness_units': 'HV', 'modulus_value': 55, 'modulus_units': 'GPa', 'notes': 'Al-1-1 (N2 at 68 bar, 445°C), machine-finished substrate + IPA wash'}
# Sending second-pass prompt for Article_9.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 80, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.14, 'ductility_units': '%', 'hardness_value': 82.5, 'hardness_units': 'HV', 'modulus_value': 59, 'modulus_units': 'GPa', 'notes': 'Al-1-2 (N2 at 68 bar, 445°C), sand-blasted substrate + IPA wash'}
# Sending second-pass prompt for Article_9.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 60, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.14, 'ductility_units': '%', 'hardness_value': 75, 'hardness_units': 'HV', 'modulus_value': 56, 'modulus_units': 'GPa', 'notes': 'Al-1-3 (N2 at 68 bar, 445°C), wire-wheel substrate + IPA wash'}
# Sending second-pass prompt for Article_9.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 75, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.14, 'ductility_units': '%', 'hardness_value': 77.5, 'hardness_units': 'HV', 'modulus_value': 58, 'modulus_units': 'GPa', 'notes': 'Al-1-4 (N2 at 68 bar, 445°C), wire-wheel + IPA wash + substrate preheat'}
# Sending second-pass prompt for Article_9.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 288, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 5.16, 'ductility_units': '%', 'hardness_value': 90, 'hardness_units': 'HV', 'modulus_value': 66, 'modulus_units': 'GPa', 'notes': 'Al-2-1 (He at 35 bar, 445°C), wire-wheel substrate + IPA wash'}
# Processing article: Article_10.pdf
# Extracting text from: documents/Article_10.pdf
# Processing article: Article_11.pdf
# Extracting text from: documents/Article_11.pdf
# Sending second-pass prompt for Article_11.pdf / experiment:
# {'yield_strength_value': 262.0, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 286.8, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 2.0, 'ductility_units': '%', 'hardness_value': 105.0, 'hardness_units': 'HV', 'modulus_value': 67.5, 'modulus_units': 'GPa', 'notes': 'As-sprayed cold-spray 6061; data from Table III'}
# Sending second-pass prompt for Article_11.pdf / experiment:
# {'yield_strength_value': 147.5, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 195.1, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 13.0, 'ductility_units': '%', 'hardness_value': 65.7, 'hardness_units': 'HV', 'modulus_value': 64.1, 'modulus_units': 'GPa', 'notes': 'Annealed cold-spray 6061 (344°C for 8 hours); data from Table III'}
# Processing article: Article_12.pdf
# Extracting text from: documents/Article_12.pdf
# Processing article: Article_13.pdf
# Skipping because PDF not found.
# Processing article: Article_14.pdf
# Extracting text from: documents/Article_14.pdf
# Sending second-pass prompt for Article_14.pdf / experiment:
# {'yield_strength_value': 285, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Micropillar compression tests on cold‐sprayed splats of Al 6061 (deposited in the T6 condition) yielded flow stresses at 2% plastic strain ranging from 280 to 290 MPa, a value comparable to the yield strength of heavily cold‐worked bulk Al 6061.'}
# Processing article: Article_15.pdf
# Extracting text from: documents/Article_15.pdf
# Sending second-pass prompt for Article_15.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 440, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-deposited (cold-sprayed) condition'}
# Sending second-pass prompt for Article_15.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 490, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3.6, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Stress-relieved condition'}
# Sending second-pass prompt for Article_15.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 465, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3.8, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'T6 condition'}
# Processing article: Article_16.pdf
# Extracting text from: documents/Article_16.pdf
# Sending second-pass prompt for Article_16.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.0, 'hardness_units': 'GPa', 'modulus_value': 62.8, 'modulus_units': 'GPa', 'notes': 'Results from nanoindentation of gas‐atomized Al 6061 powder used for cold spray deposition.'}
# Sending second-pass prompt for Article_16.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.3, 'hardness_units': 'GPa', 'modulus_value': 62.1, 'modulus_units': 'GPa', 'notes': 'Nanoindentation results on solution‐treated Al 6061 powder (solution treatment at ~545°C for 1 h) for cold spray processing.'}
# Sending second-pass prompt for Article_16.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.6, 'hardness_units': 'GPa', 'modulus_value': 72.5, 'modulus_units': 'GPa', 'notes': 'Nanoindentation results on precipitation‐hardened Al 6061 powder (heat treatment: ~545°C for 1 h followed by ~160°C for 18 h) used for cold spray deposition.'}
# Processing article: Article_17.pdf
# Extracting text from: documents/Article_17.pdf
# Processing article: Article_18.pdf
# Extracting text from: documents/Article_18.pdf
# Sending second-pass prompt for Article_18.pdf / experiment:
# {'yield_strength_value': 260, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 2.6, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Yield stress of 260 MPa is assumed based on tensile testing of similar cold‐sprayed 6061 aluminum [45]. The reported elongation at break of 2.6% (vs. 11.6% for the wrought condition) indicates the lower ductility of the as-sprayed deposit (no post-spray heat treatment).'}
# Processing article: Article_19.pdf
# Extracting text from: documents/Article_19.pdf
# Sending second-pass prompt for Article_19.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 35.6, 'ultimate_tensile_strength_units': 'GPa', 'ductility_value': 20, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 288, 'modulus_units': 'GPa', 'notes': 'MD simulation results for a 5 nm thick γ‐Al2O3 (nanoscale oxide film) present on cold-sprayed 6061 Al powders.'}
# Sending second-pass prompt for Article_19.pdf / experiment:
# {'yield_strength_value': 270, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 68.3, 'modulus_units': 'GPa', 'notes': 'Property values for the 6061 Al alloy substrate used in finite element simulations (from Ref. [44]).'}
# Processing article: Article_20.pdf
# Extracting text from: documents/Article_20.pdf
# Sending second-pass prompt for Article_20.pdf / experiment:
# {'yield_strength_value': 270, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 319, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 4.43, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed 6061 sample 1'}
# Sending second-pass prompt for Article_20.pdf / experiment:
# {'yield_strength_value': 247, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 314, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 4.96, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed 6061 sample 2'}
# Sending second-pass prompt for Article_20.pdf / experiment:
# {'yield_strength_value': 252, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 316, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 6.4, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed 6061 sample 3'}
# Sending second-pass prompt for Article_20.pdf / experiment:
# {'yield_strength_value': 237, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 310, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 5.18, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed 6061 sample 4'}
# Processing article: Article_21.pdf
# Extracting text from: documents/Article_21.pdf
# Sending second-pass prompt for Article_21.pdf / experiment:
# {'yield_strength_value': 259, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 282, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 1.6, 'ductility_units': '%', 'hardness_value': 105, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed deposit using He as the process gas.'}
# Sending second-pass prompt for Article_21.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 49, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.1, 'ductility_units': '%', 'hardness_value': 91, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed deposit using N2 as the process gas.'}
# Sending second-pass prompt for Article_21.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 223, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.5, 'ductility_units': '%', 'hardness_value': 106, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold sprayed N2 deposit processed with Conventional Heat Treatment (CHT-SA).'}
# Sending second-pass prompt for Article_21.pdf / experiment:
# {'yield_strength_value': 261, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 269, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.9, 'ductility_units': '%', 'hardness_value': 112, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold sprayed N2 deposit processed with Conventional Heat Treatment at high temperature (CHT-H-SA).'}
# Sending second-pass prompt for Article_21.pdf / experiment:
# {'yield_strength_value': 56, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 120, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 4.9, 'ductility_units': '%', 'hardness_value': 67, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold sprayed N2 deposit processed with Conventional Heat Treatment annealing at standard temperature (CHT-Ann).'}
# Sending second-pass prompt for Article_21.pdf / experiment:
# {'yield_strength_value': 57, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 122, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 7.4, 'ductility_units': '%', 'hardness_value': 72, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold sprayed N2 deposit processed with Conventional Heat Treatment annealing at elevated temperature (CHT-H-Ann).'}
# Sending second-pass prompt for Article_21.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 235, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.5, 'ductility_units': '%', 'hardness_value': 110, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold sprayed N2 deposit processed with Hot Isostatic Pressing at standard temperature (HIP-SA).'}
# Sending second-pass prompt for Article_21.pdf / experiment:
# {'yield_strength_value': 257, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 268, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 1.3, 'ductility_units': '%', 'hardness_value': 113, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold sprayed N2 deposit processed with Hot Isostatic Pressing at elevated temperature (HIP-H-SA).'}
# Sending second-pass prompt for Article_21.pdf / experiment:
# {'yield_strength_value': 57, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 123, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 5.1, 'ductility_units': '%', 'hardness_value': 71, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold sprayed N2 deposit processed with Hot Isostatic Pressing followed by annealing at standard temperature (HIP-Ann).'}
# Sending second-pass prompt for Article_21.pdf / experiment:
# {'yield_strength_value': 57, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 123, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 9.4, 'ductility_units': '%', 'hardness_value': 73, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold sprayed N2 deposit processed with Hot Isostatic Pressing followed by annealing at elevated temperature (HIP-H-Ann).'}
# Processing article: Article_22.pdf
# Extracting text from: documents/Article_22.pdf
# Sending second-pass prompt for Article_22.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 103, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.3, 'ductility_units': '%', 'hardness_value': 93, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed Al6061, horizontally built as-deposited condition (UTS measured from tensile tests).'}
# Sending second-pass prompt for Article_22.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 78, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.2, 'ductility_units': '%', 'hardness_value': 84, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed Al6061, vertically built as-deposited condition (UTS measured from tensile tests).'}
# Sending second-pass prompt for Article_22.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 238, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 6.1, 'ductility_units': '%', 'hardness_value': 88, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed Al6061, horizontally built heat-treated condition (sintering at 610°C for 5 hrs, solutionising at 530°C for 1 hr, ageing at 160°C for 4 hrs).'}
# Sending second-pass prompt for Article_22.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 241, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 5.1, 'ductility_units': '%', 'hardness_value': 96, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed Al6061, vertically built heat-treated condition (sintering at 610°C for 5 hrs, solutionising at 530°C for 1 hr, ageing at 160°C for 4 hrs).'}
# Processing article: Article_23.pdf
# Extracting text from: documents/Article_23.pdf
# Sending second-pass prompt for Article_23.pdf / experiment:
# {'yield_strength_value': 324, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 68.9, 'modulus_units': 'GPa', 'notes': 'Parameters for cold-sprayed 6061-T6 aluminum alloy were obtained via fitting general flow stress data using the MW material model.'}
# Processing article: Article_24.pdf
# Extracting text from: documents/Article_24.pdf
# Sending second-pass prompt for Article_24.pdf / experiment:
# {'yield_strength_value': 255, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 282, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 6.5, 'ductility_units': '%', 'hardness_value': 95.7, 'hardness_units': 'HV200', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed Al6061 coating produced with N2 process gas (as-deposited). Tensile data from Table 4.'}
# Sending second-pass prompt for Article_24.pdf / experiment:
# {'yield_strength_value': 110, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 110, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.2, 'ductility_units': '%', 'hardness_value': 109.6, 'hardness_units': 'HV200', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed Al6061 coating produced with N2 process gas plus ZrO2 secondary peening. Tensile data from Table 4.'}
# Sending second-pass prompt for Article_24.pdf / experiment:
# {'yield_strength_value': 82, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 82, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.1, 'ductility_units': '%', 'hardness_value': 107.4, 'hardness_units': 'HV200', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed Al6061 coating produced with He process gas. Tensile data from Table 4.'}
# Processing article: Article_25.pdf
# Extracting text from: documents/Article_25.pdf
# Sending second-pass prompt for Article_25.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 277.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.6, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 64.3, 'modulus_units': 'GPa', 'notes': 'As-deposited (MF-CS) condition with no post-spray heat treatment'}
# Sending second-pass prompt for Article_25.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 298.1, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.9, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 63.2, 'modulus_units': 'GPa', 'notes': 'Stress-relieved (SR) at 175°C for 8 h'}
# Sending second-pass prompt for Article_25.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 210.8, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 9.3, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Recrystallization annealed (RA) at 450°C for 2 h'}
# Sending second-pass prompt for Article_25.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 314.3, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 7.8, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'T6 heat treatment: solution at 535°C for 1 h, water quench, aging at 175°C for 4 h'}
# Processing article: Article_26.pdf
# Extracting text from: documents/Article_26.pdf
# Sending second-pass prompt for Article_26.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 34.3, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.07, 'ductility_units': '%', 'hardness_value': 85, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Baseline cold‐sprayed Al6061 deposit (TS-0kW-T) produced without laser assistance or hotplate heating; very low ductility.'}
# Sending second-pass prompt for Article_26.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 165, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 'NA', 'ductility_units': '%', 'hardness_value': 70, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Intermediate laser‐assisted cold spray (TS-3kW-H) using 3 kW laser power with hotplate heating; UTS increased but ductility not explicitly reported.'}
# Sending second-pass prompt for Article_26.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 167.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 15.58, 'ductility_units': '%', 'hardness_value': 50, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Optimized laser-assisted cold spray (TS-5kW-H) using 5 kW laser power with hotplate heating; significant increase in both UTS and ductility with a softened deposit.'}
# Processing article: Article_27.pdf
# Extracting text from: documents/Article_27.pdf
# Sending second-pass prompt for Article_27.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 86.5, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Average microhardness of the N2‐sprayed Al 6061-T6 coating measured as 86.5 ±7 HV.'}
# Sending second-pass prompt for Article_27.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 105, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Average microhardness of the He‐sprayed Al 6061-T6 coating measured as 105 ±4 HV.'}
# Processing article: Article_28.pdf
# Extracting text from: documents/Article_28.pdf
# Processing article: Article_29.pdf
# Extracting text from: documents/Article_29.pdf
# Sending second-pass prompt for Article_29.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 135, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold spray coating deposited using the as‐received (feedstock) Al 6061 powder; hardness measured 24 h after spraying.'}
# Sending second-pass prompt for Article_29.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 123.5, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold spray coating deposited using the solution heat‐treated Al 6061 powder; hardness measured 24 h after spraying.'}
# Processing article: Article_30.pdf
# Extracting text from: documents/Article_30.pdf
# Sending second-pass prompt for Article_30.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 34.3, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.07, 'ductility_units': '%', 'hardness_value': 85, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed with no external heating (0 kW).'}
# Sending second-pass prompt for Article_30.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 167.6, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 15.58, 'ductility_units': '%', 'hardness_value': 50, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Laser-assisted cold spray with 5 kW, hotplate at ~500°C.'}
# Processing article: Article_31.pdf
# Extracting text from: documents/Article_31.pdf
# Processing article: Article_32.pdf
# Extracting text from: documents/Article_32.pdf
# Processing article: Article_33.pdf
# Extracting text from: documents/Article_33.pdf
# Processing article: Article_34.pdf
# Extracting text from: documents/Article_34.pdf
# Sending second-pass prompt for Article_34.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 55.18, 'hardness_units': 'HRC', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed Al 6061 using nitrogen carrier gas, as-sprayed (original) condition; hardness measured by Rockwell-type C microhardness.'}
# Sending second-pass prompt for Article_34.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 43.74, 'hardness_units': 'HRC', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed Al 6061 using nitrogen carrier gas, annealed condition; hardness measured by Rockwell-type C microhardness.'}
# Sending second-pass prompt for Article_34.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 73.8, 'hardness_units': 'HRC', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed Al 6061 using helium carrier gas, as-sprayed (original) condition; hardness measured by Rockwell-type C microhardness.'}
# Sending second-pass prompt for Article_34.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 54.18, 'hardness_units': 'HRC', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold-sprayed Al 6061 using helium carrier gas, annealed condition; hardness measured by Rockwell-type C microhardness.'}
# Processing article: Article_35.pdf
# Extracting text from: documents/Article_35.pdf
# Sending second-pass prompt for Article_35.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 70, 'hardness_units': 'HV0.05', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed 6061 coating'}
# Sending second-pass prompt for Article_35.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 67, 'hardness_units': 'HV0.05', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed blended 6061-TiC coating'}
# Sending second-pass prompt for Article_35.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 91, 'hardness_units': 'HV0.05', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed satellited 6061-TiC coating'}
# Sending second-pass prompt for Article_35.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 83, 'hardness_units': 'HV0.05', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Heat-treated satellited 6061-TiC coating at 345°C for 2h'}
# Processing article: Article_36.pdf
# Extracting text from: documents/Article_36.pdf
# Processing article: Article_37.pdf
# Extracting text from: documents/Article_37.pdf
# Processing article: Article_38.pdf
# Extracting text from: documents/Article_38.pdf
# Sending second-pass prompt for Article_38.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'The paper reports results on cold‐sprayed Al6061 coatings (e.g. online particle monitoring, coating thickness, and comparisons of coating adhesion and hardness relative to standard heat‐treated conditions) produced by high‐pressure cold spray using process parameters (30–40 bar, 300–400°C) on aluminum/steel substrates. However, no explicit numeric values for yield strength, ultimate tensile strength, ductility, or elastic modulus were provided.'}
# Processing article: Article_39.pdf
# Extracting text from: documents/Article_39.pdf
# Sending second-pass prompt for Article_39.pdf / experiment:
# {'yield_strength_value': 174, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 0.33, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 61.9, 'modulus_units': 'GPa', 'notes': 'NHT – Non‐heat‐treated cold spray additively manufactured Aluminum 6061.'}
# Sending second-pass prompt for Article_39.pdf / experiment:
# {'yield_strength_value': 252, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 263, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 1.63, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 60.8, 'modulus_units': 'GPa', 'notes': '595C – Post-deposition heat treatment at 595°C for 240 min in air, then 550°C for 10 min (water quench) and 225°C for 270 min.'}
# Sending second-pass prompt for Article_39.pdf / experiment:
# {'yield_strength_value': 266, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 280, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 2.23, 'ductility_units': '%', 'hardness_value': 103.0, 'hardness_units': 'HV', 'modulus_value': 61.5, 'modulus_units': 'GPa', 'notes': '615C – Post-deposition heat treatment at 615°C for 240 min in air, then 550°C for 10 min (water quench) and 225°C for 270 min.'}
# Sending second-pass prompt for Article_39.pdf / experiment:
# {'yield_strength_value': 178, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 254, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 7.99, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 64.1, 'modulus_units': 'GPa', 'notes': '615C extended – Heat treatment at 615°C for 420 min in air, then 550°C for 30 min (water quench) and 160°C for 120 min.'}
# Sending second-pass prompt for Article_39.pdf / experiment:
# {'yield_strength_value': 219, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 238, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3.0, 'ductility_units': '%', 'hardness_value': 76.5, 'hardness_units': 'HV', 'modulus_value': 60.8, 'modulus_units': 'GPa', 'notes': '615C charcoal – Heat treatment at 615°C for 240 min in an air atmosphere modified by a carbon monoxide (charcoal) environment, then 550°C for 10 min (water quench) and 225°C for 270 min.'}
# Processing article: Article_40.pdf
# Extracting text from: documents/Article_40.pdf
# Processing article: Article_41.pdf
# Extracting text from: documents/Article_41.pdf
# Sending second-pass prompt for Article_41.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 18.51, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Tensile bonding strength measured by a tensile test on a cold‐sprayed Fe‐based amorphous alloy coating deposited on a 6061 Al alloy substrate.'}
# Processing article: Article_42.pdf
# Extracting text from: documents/Article_42.pdf
# Sending second-pass prompt for Article_42.pdf / experiment:
# {'yield_strength_value': 100, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold spray coating produced using the CGT process with N2 at 400°C; effective yield stress was estimated from the residual stress model (see Table 6)'}
# Processing article: Article_43.pdf
# Extracting text from: documents/Article_43.pdf
# Sending second-pass prompt for Article_43.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 3.75, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Conventional coating produced from as-atomized 2618 aluminum alloy powder sprayed onto Al 6061 substrate (nanoindentation hardness measured at 500 nm depth).'}
# Sending second-pass prompt for Article_43.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 4.41, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Nanocrystalline coating produced from as-cryomilled 2618 aluminum alloy powder sprayed onto Al 6061 substrate (nanoindentation hardness measured at 500 nm depth).'}
# Processing article: Article_44.pdf
# Skipping because PDF not found.
# Processing article: Article_45.pdf
# Extracting text from: documents/Article_45.pdf
# Processing article: Article_46.pdf
# Extracting text from: documents/Article_46.pdf
# Sending second-pass prompt for Article_46.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.26, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Nanoindentation measurement on as‐atomized gas‐atomized Al 6061 powder (average value reported as 1.26 ± 0.15 GPa)'}
# Sending second-pass prompt for Article_46.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.29, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Nanoindentation hardness of Al 6061 powder after heating to 540°C and immediate quench (0 min hold)'}
# Sending second-pass prompt for Article_46.pdf / experiment:
# ...
# Sending second-pass prompt for Article_84.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.18, 'hardness_units': 'GPa', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Substrate (6061‐T6) microhardness was measured using Vickers testing – values near the cold‐spray deposit averaged around 1.18 GPa (with regional variation from ~1.08 to 1.46 GPa). No yield, tensile, ductility, or modulus data were provided.'}
# Processing article: Article_85.pdf
# Extracting text from: documents/Article_85.pdf
# Sending second-pass prompt for Article_85.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 19.5, 'modulus_units': 'GPa', 'notes': 'Air sprayed cold‐sprayed Al 6061 coating; modulus measured at 400°C via DMA with in‐situ splat sintering.'}
# Sending second-pass prompt for Article_85.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 38.5, 'modulus_units': 'GPa', 'notes': 'Helium sprayed cold‐sprayed Al 6061 coating; modulus measured at 400°C via DMA under in‐situ splat sintering.'}
# Processing article: Article_86.pdf
# Extracting text from: documents/Article_86.pdf
# Processing article: Article_87.pdf
# Extracting text from: documents/Article_87.pdf
# Sending second-pass prompt for Article_87.pdf / experiment:
# {'yield_strength_value': 290, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Maximum flow stress measured via micropillar compression tests on cold‐sprayed splats, which is noted to be similar to the yield strength of bulk, cold-worked T6 Al 6061.'}
# Processing article: Article_88.pdf
# Extracting text from: documents/Article_88.pdf
# Sending second-pass prompt for Article_88.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 160.4, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 2.8, 'ductility_units': '%', 'hardness_value': 54.5, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'These values are from the cold‐sprayed repair (RCS samples) of a 6A01‐T5 aluminum alloy (used for high‐speed train components) using Al‐based powders. Ultimate tensile strength and elongation (ductility) were obtained from tensile tests while microhardness was measured on the cross‐section; no yield strength or elastic modulus data were provided.'}
# Processing article: Article_89.pdf
# Skipping due to filename containing '56' or '89'.
# Processing article: Article_90.pdf
# Extracting text from: documents/Article_90.pdf
# Processing article: Article_91.pdf
# Extracting text from: documents/Article_91.pdf
# Processing article: Article_92.pdf
# Extracting text from: documents/Article_92.pdf
# Processing article: Article_93.pdf
# Extracting text from: documents/Article_93.pdf
# Sending second-pass prompt for Article_93.pdf / experiment:
# {'yield_strength_value': 324, 'yield_strength_units': 'MPa', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 68.9, 'modulus_units': 'GPa', 'notes': 'Material data for AA-6061-T6 used in simulation. The Johnson–Cook constitutive model parameter A (=324 MPa) is taken as the yield strength, while no values for ultimate tensile strength, ductility, or hardness were reported.'}
# Processing article: Article_94.pdf
# Extracting text from: documents/Article_94.pdf
# Processing article: Article_95.pdf
# Extracting text from: documents/Article_95.pdf
# Processing article: Article_96.pdf
# Extracting text from: documents/Article_96.pdf
# Sending second-pass prompt for Article_96.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 199, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 1.92, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'ASTM E8 type tensile testing for initial qualification (Sample 1) on cold-sprayed 6061 aluminum deposit'}
# Sending second-pass prompt for Article_96.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 203, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 2.01, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'ASTM E8 type tensile testing for initial qualification (Sample 2) on cold-sprayed 6061 aluminum deposit'}
# Sending second-pass prompt for Article_96.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 272, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 2.91, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Tensile testing of bulk cold spray deposit material for final process repair qualification (Sample 1)'}
# Sending second-pass prompt for Article_96.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 251, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 3.02, 'ductility_units': '%', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Tensile testing of bulk cold spray deposit material for final process repair qualification (Sample 2)'}
# Sending second-pass prompt for Article_96.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 87, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Hardness measured on the cold-sprayed deposit on the actuator bore mockup using a 100 g load'}
# Processing article: Article_97.pdf
# Extracting text from: documents/Article_97.pdf
# Processing article: Article_98.pdf
# Extracting text from: documents/Article_98.pdf
# Sending second-pass prompt for Article_98.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 74, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 6.7, 'ductility_units': '%', 'hardness_value': 45, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Cold spray (CS) sample measured along the processing direction (PD); UTS = 74 MPa and elongation = 6.7% reported.'}
# Sending second-pass prompt for Article_98.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 166, 'ultimate_tensile_strength_units': 'MPa', 'ductility_value': 45.4, 'ductility_units': '%', 'hardness_value': 55, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'CFAM sample (cold spray deposition followed by friction stir processing) measured along PD; UTS = 166 MPa and elongation = 45.4% reported.'}
# Processing article: Article_99.pdf
# Extracting text from: documents/Article_99.pdf
# Processing article: Article_100.pdf
# Extracting text from: documents/Article_100.pdf
# Sending second-pass prompt for Article_100.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 1.322, 'hardness_units': 'GPa', 'modulus_value': 87.9, 'modulus_units': 'GPa', 'notes': 'Cold spray coating prepared using as‐received 6061 powder; nanoindentation measurement at 1000 nm depth'}
# Sending second-pass prompt for Article_100.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 2.621, 'hardness_units': 'GPa', 'modulus_value': 84.4, 'modulus_units': 'GPa', 'notes': 'Cold spray coating prepared using LN2 ball milled 6061 powder; nanoindentation measurement at 1000 nm depth, with hardness approximately doubled relative to as‐received coating'}
# Processing article: Article_101.pdf
# Extracting text from: documents/Article_101.pdf
# Processing article: Article_102.pdf
# Extracting text from: documents/Article_102.pdf
# Sending second-pass prompt for Article_102.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 82, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'As-sprayed B4C/6061Al composite coating produced by cold spraying; sample exhibited a hardness of ~82 HV with noted local inhomogeneity and poor splat bonding.'}
# Sending second-pass prompt for Article_102.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Heat-treated coating (post cold spray heat treatment at 350°C for 4h) showed improved interfacial bonding but a significantly decreased hardness compared to the as‐sprayed condition.'}
# Sending second-pass prompt for Article_102.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 89, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Hot-rolled coating (cold spraying followed by hot rolling with a 20% thickness reduction) achieved the highest hardness of 89 HV and exhibited enhanced bonding strength.'}
# Processing article: Article_103.pdf
# Extracting text from: documents/Article_103.pdf
# Processing article: Article_104.pdf
# Extracting text from: documents/Article_104.pdf
# Processing article: Article_105.pdf
# Extracting text from: documents/Article_105.pdf
# Sending second-pass prompt for Article_105.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Praxair Surface Technologies deposited AA 6061 (along with AA 5056) coatings on thin walls (<1.5mm) with thickness exceeding 4mm; the coatings exhibited very dense microstructures and an adhesive strength greater than 60MPa.'}
# Sending second-pass prompt for Article_105.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 'NA', 'hardness_units': 'NA', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Pratt & Whitney Rocketdyne evaluated cold sprayed AA 6061 for fan case corrosion and structural repair. The as-sprayed AA 6061 coating showed low ductility due to work hardening, while a full annealing treatment resulted in properties comparable to AMS 4025 plate; adhesive strength of approximately 70MPa was reported for Pandalloy deposits on the AA 6061 base material.'}
# Processing article: Article_106.pdf
# Extracting text from: documents/Article_106.pdf
# Processing article: Article_107.pdf
# Skipping because PDF not found.
# Processing article: Article_108.pdf
# Extracting text from: documents/Article_108.pdf
# Processing article: Article_109.pdf
# Extracting text from: documents/Article_109.pdf
# Processing article: Article_110.pdf
# Extracting text from: documents/Article_110.pdf
# Sending second-pass prompt for Article_110.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 84.7, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Results from cold‐sprayed as‐received Al6061 on T6-Al6061 substrate; microhardness measured on powder particles (CS-054). No yield strength, tensile strength, ductility, or modulus values reported.'}
# Sending second-pass prompt for Article_110.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 69.3, 'hardness_units': 'HV', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Results from cold‐sprayed solution heat‐treated Al6061 on T6-Al6061 substrate; microhardness measured on powder particles (CS-056). No yield strength, tensile strength, ductility, or modulus values reported.'}
# Processing article: Article_111.pdf
# Extracting text from: documents/Article_111.pdf
# Processing article: Article_112.pdf
# Extracting text from: documents/Article_112.pdf
# Sending second-pass prompt for Article_112.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 195.4, 'hardness_units': 'Hv0.1', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Minimum microhardness recorded for cold‐sprayed Cu coating on 6061T6 Al alloy substrate at 800°C and 4 MPa'}
# Sending second-pass prompt for Article_112.pdf / experiment:
# {'yield_strength_value': 'NA', 'yield_strength_units': 'NA', 'ultimate_tensile_strength_value': 'NA', 'ultimate_tensile_strength_units': 'NA', 'ductility_value': 'NA', 'ductility_units': 'NA', 'hardness_value': 205.3, 'hardness_units': 'Hv0.1', 'modulus_value': 'NA', 'modulus_units': 'NA', 'notes': 'Maximum microhardness recorded for cold‐sprayed Cu coating on 6061T6 Al alloy substrate at 600°C and 5.5 MPa'}
# Processing article: Article_113.pdf
# Skipping because PDF not found.
# Processing article: Article_114.pdf
# Skipping because PDF not found.
# Processing article: Article_115.pdf
# Skipping because PDF not found.
# Processing article: Article_116.pdf
# Skipping because PDF not found.
# Processing article: Article_117.pdf
# Skipping because PDF not found.
# Processing article: Article_118.pdf
# Skipping because PDF not found.
# Processing article: Article_119.pdf
# Skipping because PDF not found.
# Processing article: Article_120.pdf
# Skipping because PDF not found.
# Processing article: Article_121.pdf
# Skipping because PDF not found.
# Processing article: Article_122.pdf
# Skipping because PDF not found.
# Processing article: Article_123.pdf
# Skipping because PDF not found.
# Processing article: Article_124.pdf
# Skipping because PDF not found.
# Processing article: Article_125.pdf
# Skipping because PDF not found.
# All done! Final file saved at: /Users/sprice/Documents/GitHub/coldSprayTextExtraction/productionalized/modelOutputs3-11/o3-mini_promptv2_high_merged_withParams.json
